# %%
from confluent_kafka import Consumer, KafkaException
from pymongo import MongoClient
import json

# ✅ Kafka Configuration
KAFKA_BOOTSTRAP_SERVER = "Replace it with your bootstrap server."
KAFKA_API_KEY = "Replace with your actual API Key"
KAFKA_API_SECRET = "Replace with your actual API Secret"  
KAFKA_TOPIC = "txndata"
KAFKA_GROUP_ID = "fraud-detection-group"

# ✅ MongoDB Configuration
MONGO_URI = "Replace with your mongodb uri."
MONGO_DB = "txn_db"
MONGO_COLLECTION = "fraud_alerts"

client = MongoClient(MONGO_URI)
db = client[MONGO_DB]
collection = db[MONGO_COLLECTION]

def if_fraudulent(transaction):
      fraud_score = transaction['amount']/5000
      return fraud_score > 0.8
conf = {
    'bootstrap.servers': KAFKA_BOOTSTRAP_SERVER,
    'security.protocol': 'SASL_SSL',
    'sasl.mechanism': 'PLAIN',
    'sasl.username': KAFKA_API_KEY,
    'sasl.password': KAFKA_API_SECRET,
    'group.id':KAFKA_GROUP_ID,
    'auto.offset.reset':'earliest'
}

consumer = Consumer(conf)
consumer.subscribe([KAFKA_TOPIC])

print(f"listning for the msg on kafka topics :{KAFKA_TOPIC}")

try :
    while True:
        msg = consumer.poll(1.0)
        if msg is None:
            continue
        if msg.error():
            print(f"kafka erro not able to get the msg {msg.error()}")
            continue
        transaction = json.loads(msg.value().decode('utf-8'))
        print(f"received msg from kafka is {transaction}")

        if if_fraudulent(transaction):
            print("fraud detected ",transaction )
            collection.insert_one(transaction)
except Exception as e :
    print(e)
finally:
    consumer.close()
# Out:
# listning for the msg on kafka topics :txndata
# received msg from kafka is {'transaction_id': '09fb1749-20b2-434a-a941-6d1ebe192ac8', 'timestamp': 1742582665, 'user_id': 14556, 'amount': 3312.72, 'transaction_type': 'withdrawal', 'location': 'Escobartown', 'mearchant': 'Jackson, Banks and Dickerson', 'card_number': '349732511596353'}
# received msg from kafka is {'transaction_id': 'fe6bb1ee-5448-458b-9c97-a4adab008139', 'timestamp': 1742582671, 'user_id': 48961, 'amount': 3202.38, 'transaction_type': 'purchase', 'location': 'Carlaport', 'mearchant': 'Wilson LLC', 'card_number': '30096507207902'}
# received msg from kafka is {'transaction_id': '7a2ada52-530d-46f7-9825-1fd8160f811d', 'timestamp': 1742582673, 'user_id': 88200, 'amount': 4276.53, 'transaction_type': 'transfer', 'location': 'Arnoldchester', 'mearchant': 'Burke-Jones', 'card_number': '30106194575360'}
# fraud detected  {'transaction_id': '7a2ada52-530d-46f7-9825-1fd8160f811d', 'timestamp': 1742582673, 'user_id': 88200, 'amount': 4276.53, 'transaction_type': 'transfer', 'location': 'Arnoldchester', 'mearchant': 'Burke-Jones', 'card_number': '30106194575360'}
# received msg from kafka is {'transaction_id': 'a8a5a2ff-cf33-43a6-89d9-fd8c4d2c648f', 'timestamp': 1742582686, 'user_id': 30662, 'amount': 2479.85, 'transaction_type': 'withdrawal', 'location': 'Billyland', 'mearchant': 'Brown Inc', 'card_number': '3508448541548105'}
# received msg from kafka is {'transaction_id': 'a2d85af0-9c57-426e-a296-df910b4633b3', 'timestamp': 1742582691, 'user_id': 82096, 'amount': 2432.7, 'transaction_type': 'purchase', 'location': 'West Marcusmouth', 'mearchant': 'Ibarra, Holloway and Mccarthy', 'card_number': '4079179493499'}
# received msg from kafka is {'transaction_id': '0b5fd405-c443-4a2e-bf33-82f6c1b54308', 'timestamp': 1742582697, 'user_id': 26269, 'amount': 4224.93, 'transaction_type': 'withdrawal', 'location': 'Scottborough', 'mearchant': 'Davis-Alexander', 'card_number': '372909049730585'}
# fraud detected  {'transaction_id': '0b5fd405-c443-4a2e-bf33-82f6c1b54308', 'timestamp': 1742582697, 'user_id': 26269, 'amount': 4224.93, 'transaction_type': 'withdrawal', 'location': 'Scottborough', 'mearchant': 'Davis-Alexander', 'card_number': '372909049730585'}
# received msg from kafka is {'transaction_id': '380f8748-e251-4e20-a69d-f89c446b58ec', 'timestamp': 1742582703, 'user_id': 83982, 'amount': 2436.1, 'transaction_type': 'withdrawal', 'location': 'Joshuaberg', 'mearchant': 'Curtis LLC', 'card_number': '676295958992'}
# received msg from kafka is {'transaction_id': 'fd811d81-77b9-48cb-91c8-6ddb363af49e', 'timestamp': 1742582707, 'user_id': 76710, 'amount': 762.01, 'transaction_type': 'transfer', 'location': 'Denisefurt', 'mearchant': 'Reed, Armstrong and Newton', 'card_number': '344716981566124'}
# received msg from kafka is {'transaction_id': '3d53da20-f2d3-4d89-84f0-eb30885282a4', 'timestamp': 1742582710, 'user_id': 54672, 'amount': 4610.11, 'transaction_type': 'purchase', 'location': 'Elizabethport', 'mearchant': 'Smith-Olson', 'card_number': '4084247693852392070'}
# fraud detected  {'transaction_id': '3d53da20-f2d3-4d89-84f0-eb30885282a4', 'timestamp': 1742582710, 'user_id': 54672, 'amount': 4610.11, 'transaction_type': 'purchase', 'location': 'Elizabethport', 'mearchant': 'Smith-Olson', 'card_number': '4084247693852392070'}
# received msg from kafka is {'transaction_id': '35a32fa2-52b7-409b-baee-2d2d4073a1dc', 'timestamp': 1742582723, 'user_id': 57204, 'amount': 2398.7, 'transaction_type': 'transfer', 'location': 'Williamberg', 'mearchant': 'Stuart, Oliver and Horn', 'card_number': '4767136287141'}
# received msg from kafka is {'transaction_id': '1ca688b2-4b80-428f-a6cd-f50c19ca274c', 'timestamp': 1742582724, 'user_id': 58523, 'amount': 560.0, 'transaction_type': 'transfer', 'location': 'West Conniechester', 'mearchant': 'Thomas, Lucas and Marshall', 'card_number': '2716970772989856'}
# received msg from kafka is {'transaction_id': 'bc02eaea-0f51-4dcb-8409-8764b1e39515', 'timestamp': 1742582726, 'user_id': 88023, 'amount': 4727.88, 'transaction_type': 'transfer', 'location': 'East Maria', 'mearchant': 'Blake-Griffin', 'card_number': '4461149996554613'}
# fraud detected  {'transaction_id': 'bc02eaea-0f51-4dcb-8409-8764b1e39515', 'timestamp': 1742582726, 'user_id': 88023, 'amount': 4727.88, 'transaction_type': 'transfer', 'location': 'East Maria', 'mearchant': 'Blake-Griffin', 'card_number': '4461149996554613'}
# received msg from kafka is {'transaction_id': '4bf42adc-fcb3-4c69-b55c-f17de81779ea', 'timestamp': 1742582727, 'user_id': 58272, 'amount': 4754.17, 'transaction_type': 'purchase', 'location': 'South Roberthaven', 'mearchant': 'Mason, Black and Young', 'card_number': '180069416290168'}
# fraud detected  {'transaction_id': '4bf42adc-fcb3-4c69-b55c-f17de81779ea', 'timestamp': 1742582727, 'user_id': 58272, 'amount': 4754.17, 'transaction_type': 'purchase', 'location': 'South Roberthaven', 'mearchant': 'Mason, Black and Young', 'card_number': '180069416290168'}
# received msg from kafka is {'transaction_id': '436e85c1-bd2a-43fd-ab8f-e011053aaad4', 'timestamp': 1742582729, 'user_id': 23919, 'amount': 874.44, 'transaction_type': 'transfer', 'location': 'Timothyborough', 'mearchant': 'Moss Ltd', 'card_number': '3519672885497671'}
# received msg from kafka is {'transaction_id': '7551c046-8759-4000-9eb8-d1b4dc6108ac', 'timestamp': 1742582736, 'user_id': 43184, 'amount': 4367.93, 'transaction_type': 'transfer', 'location': 'New Amyfurt', 'mearchant': 'Patterson Inc', 'card_number': '4539851180201'}
# fraud detected  {'transaction_id': '7551c046-8759-4000-9eb8-d1b4dc6108ac', 'timestamp': 1742582736, 'user_id': 43184, 'amount': 4367.93, 'transaction_type': 'transfer', 'location': 'New Amyfurt', 'mearchant': 'Patterson Inc', 'card_number': '4539851180201'}
# received msg from kafka is {'transaction_id': 'e480395f-a2fa-4dce-a91f-52825e7d774a', 'timestamp': 1742582738, 'user_id': 23531, 'amount': 2138.45, 'transaction_type': 'transfer', 'location': 'West Desireehaven', 'mearchant': 'Nguyen, Wells and Harris', 'card_number': '4006278144109699'}
# received msg from kafka is {'transaction_id': '03583494-6c81-45f7-86f0-3c9536155e91', 'timestamp': 1742582740, 'user_id': 71789, 'amount': 2682.97, 'transaction_type': 'purchase', 'location': 'Lake Kathleen', 'mearchant': 'Perry-Vaughn', 'card_number': '213153748400959'}
# received msg from kafka is {'transaction_id': '78d77083-e97c-4700-9156-ee8fc4ec11c7', 'timestamp': 1742582745, 'user_id': 99583, 'amount': 1962.39, 'transaction_type': 'purchase', 'location': 'Jeremyborough', 'mearchant': 'Gibson Inc', 'card_number': '676268945158'}
# received msg from kafka is {'transaction_id': 'a5de725d-40fc-4cc4-9133-d7ad72b60051', 'timestamp': 1742582746, 'user_id': 48543, 'amount': 2046.73, 'transaction_type': 'transfer', 'location': 'South Melissa', 'mearchant': 'Adams, Jones and Johnson', 'card_number': '5417549254235163'}
# received msg from kafka is {'transaction_id': 'b3ab7fc2-9b12-45a6-8dad-984c7688137e', 'timestamp': 1742582747, 'user_id': 88153, 'amount': 2074.37, 'transaction_type': 'purchase', 'location': 'Kimburgh', 'mearchant': 'Gonzalez-Taylor', 'card_number': '4754981953753'}
# received msg from kafka is {'transaction_id': '76fb924b-b271-42e5-adf7-a03edb654a57', 'timestamp': 1742582748, 'user_id': 42464, 'amount': 3008.58, 'transaction_type': 'withdrawal', 'location': 'Newmanbury', 'mearchant': 'Grant-Johnson', 'card_number': '4328371284143'}
# received msg from kafka is {'transaction_id': 'e5c2ec6c-bb02-446b-a963-75170554c30a', 'timestamp': 1742582749, 'user_id': 90737, 'amount': 4615.33, 'transaction_type': 'purchase', 'location': 'South Allison', 'mearchant': 'Reed LLC', 'card_number': '2225042285728702'}
# fraud detected  {'transaction_id': 'e5c2ec6c-bb02-446b-a963-75170554c30a', 'timestamp': 1742582749, 'user_id': 90737, 'amount': 4615.33, 'transaction_type': 'purchase', 'location': 'South Allison', 'mearchant': 'Reed LLC', 'card_number': '2225042285728702'}
# received msg from kafka is {'transaction_id': '7ff5860b-0977-49de-bc5b-cbc8e4530b47', 'timestamp': 1742582751, 'user_id': 98883, 'amount': 1590.39, 'transaction_type': 'withdrawal', 'location': 'Lake Mercedesfort', 'mearchant': 'Torres Ltd', 'card_number': '060404950580'}
# received msg from kafka is {'transaction_id': 'bb2f324e-1200-4342-9e46-c8bad4d2cffa', 'timestamp': 1742582771, 'user_id': 23002, 'amount': 4140.56, 'transaction_type': 'transfer', 'location': 'East Michaelton', 'mearchant': 'Elliott, Young and Rice', 'card_number': '30382565946551'}
# fraud detected  {'transaction_id': 'bb2f324e-1200-4342-9e46-c8bad4d2cffa', 'timestamp': 1742582771, 'user_id': 23002, 'amount': 4140.56, 'transaction_type': 'transfer', 'location': 'East Michaelton', 'mearchant': 'Elliott, Young and Rice', 'card_number': '30382565946551'}
# received msg from kafka is {'transaction_id': '2b825c63-8e4d-4214-a05e-eca434229e2f', 'timestamp': 1742582782, 'user_id': 71709, 'amount': 2464.21, 'transaction_type': 'withdrawal', 'location': 'Rayland', 'mearchant': 'Figueroa and Sons', 'card_number': '4096998642172888'}
# received msg from kafka is {'transaction_id': '33aae165-2281-4c1b-97ce-80ba55d1713f', 'timestamp': 1742582786, 'user_id': 32708, 'amount': 4950.01, 'transaction_type': 'transfer', 'location': 'West Susanview', 'mearchant': 'Thomas, Torres and Duarte', 'card_number': '5132309569409944'}
# fraud detected  {'transaction_id': '33aae165-2281-4c1b-97ce-80ba55d1713f', 'timestamp': 1742582786, 'user_id': 32708, 'amount': 4950.01, 'transaction_type': 'transfer', 'location': 'West Susanview', 'mearchant': 'Thomas, Torres and Duarte', 'card_number': '5132309569409944'}
# received msg from kafka is {'transaction_id': 'b3cbdabf-24c6-40ec-a2aa-5fed4a95d8ed', 'timestamp': 1742582814, 'user_id': 97457, 'amount': 1280.83, 'transaction_type': 'purchase', 'location': 'New Sarahaven', 'mearchant': 'Nolan, Castillo and Schaefer', 'card_number': '340761105427567'}
# received msg from kafka is {'transaction_id': '074f82d5-4dba-4e25-be6f-7837eecc4eee', 'timestamp': 1742582816, 'user_id': 45842, 'amount': 1380.25, 'transaction_type': 'withdrawal', 'location': 'Hollandfurt', 'mearchant': 'Robinson Inc', 'card_number': '30395281364115'}
# received msg from kafka is {'transaction_id': '15266d08-04c2-459a-b99c-4e73f1cb1acc', 'timestamp': 1742582840, 'user_id': 12810, 'amount': 4458.85, 'transaction_type': 'withdrawal', 'location': 'South Chris', 'mearchant': 'Mckay-Leblanc', 'card_number': '2600142202614087'}
# fraud detected  {'transaction_id': '15266d08-04c2-459a-b99c-4e73f1cb1acc', 'timestamp': 1742582840, 'user_id': 12810, 'amount': 4458.85, 'transaction_type': 'withdrawal', 'location': 'South Chris', 'mearchant': 'Mckay-Leblanc', 'card_number': '2600142202614087'}
# received msg from kafka is {'transaction_id': 'f5aa55cd-78f6-4a2a-95ff-ab5eddd902b9', 'timestamp': 1742582846, 'user_id': 64485, 'amount': 2458.55, 'transaction_type': 'withdrawal', 'location': 'North Gregoryfort', 'mearchant': 'Sanchez PLC', 'card_number': '3513975120409799'}
# received msg from kafka is {'transaction_id': '737b720d-589b-490a-80a3-08ae3195cfe5', 'timestamp': 1742582848, 'user_id': 69469, 'amount': 3067.83, 'transaction_type': 'withdrawal', 'location': 'South Sophia', 'mearchant': 'Norris-Snow', 'card_number': '4382357044698204430'}
# received msg from kafka is {'transaction_id': '70a51bd8-13b0-43c5-85e0-9d6714591070', 'timestamp': 1742582851, 'user_id': 50919, 'amount': 4967.89, 'transaction_type': 'purchase', 'location': 'Timothyland', 'mearchant': 'Olson-Patton', 'card_number': '2698674876650792'}
# fraud detected  {'transaction_id': '70a51bd8-13b0-43c5-85e0-9d6714591070', 'timestamp': 1742582851, 'user_id': 50919, 'amount': 4967.89, 'transaction_type': 'purchase', 'location': 'Timothyland', 'mearchant': 'Olson-Patton', 'card_number': '2698674876650792'}
# received msg from kafka is {'transaction_id': '79a750bd-799a-4e70-befc-d7e4cb3e47f5', 'timestamp': 1742582858, 'user_id': 99583, 'amount': 2710.16, 'transaction_type': 'purchase', 'location': 'Waltermouth', 'mearchant': 'Jones-Blair', 'card_number': '4746510522638633'}
# received msg from kafka is {'transaction_id': '8abe970d-82ca-4b79-ac4b-5ff806543d02', 'timestamp': 1742582859, 'user_id': 62039, 'amount': 1545.77, 'transaction_type': 'purchase', 'location': 'Andrewstad', 'mearchant': 'Petty and Sons', 'card_number': '4200300066611504'}
# received msg from kafka is {'transaction_id': '35f88219-5043-4d12-8b68-8b15b3cfa1b2', 'timestamp': 1742582870, 'user_id': 13927, 'amount': 4089.54, 'transaction_type': 'transfer', 'location': 'Hopkinschester', 'mearchant': 'Nelson, Campbell and Alvarado', 'card_number': '4058407344970066'}
# fraud detected  {'transaction_id': '35f88219-5043-4d12-8b68-8b15b3cfa1b2', 'timestamp': 1742582870, 'user_id': 13927, 'amount': 4089.54, 'transaction_type': 'transfer', 'location': 'Hopkinschester', 'mearchant': 'Nelson, Campbell and Alvarado', 'card_number': '4058407344970066'}
# received msg from kafka is {'transaction_id': '9d7fc264-ae6c-4b65-bcbd-db3d8403e992', 'timestamp': 1742582872, 'user_id': 97457, 'amount': 4385.51, 'transaction_type': 'transfer', 'location': 'Leonside', 'mearchant': 'Vaughn PLC', 'card_number': '4923476533052922'}
# fraud detected  {'transaction_id': '9d7fc264-ae6c-4b65-bcbd-db3d8403e992', 'timestamp': 1742582872, 'user_id': 97457, 'amount': 4385.51, 'transaction_type': 'transfer', 'location': 'Leonside', 'mearchant': 'Vaughn PLC', 'card_number': '4923476533052922'}
# received msg from kafka is {'transaction_id': 'f2be48b6-93a3-4c2e-a12c-1c2ad7a4ec5b', 'timestamp': 1742582873, 'user_id': 27795, 'amount': 1858.17, 'transaction_type': 'transfer', 'location': 'North Elizabeth', 'mearchant': 'Smith-Cruz', 'card_number': '630455462055'}
# received msg from kafka is {'transaction_id': '0e8b0f2a-c6fe-4fcc-9ab4-d8c7ddd663bb', 'timestamp': 1742582880, 'user_id': 54322, 'amount': 1377.06, 'transaction_type': 'transfer', 'location': 'Shawnberg', 'mearchant': 'Mack LLC', 'card_number': '4177271598072605444'}
# received msg from kafka is {'transaction_id': 'debab5aa-d4b1-413f-83d0-3ef89e3924be', 'timestamp': 1742582887, 'user_id': 73815, 'amount': 3972.31, 'transaction_type': 'transfer', 'location': 'Fernandezborough', 'mearchant': 'Boyle LLC', 'card_number': '3515740889773837'}
# received msg from kafka is {'transaction_id': 'd5661d1a-f80f-4e65-9420-442b4f6bcf4f', 'timestamp': 1742582658, 'user_id': 14993, 'amount': 2246.19, 'transaction_type': 'transfer', 'location': 'Samanthaberg', 'mearchant': 'Johnson, Briggs and Reed', 'card_number': '639067137062'}
# received msg from kafka is {'transaction_id': '5bfca1ab-5808-4899-8faa-77c5183de092', 'timestamp': 1742582676, 'user_id': 36394, 'amount': 1392.25, 'transaction_type': 'purchase', 'location': 'Gallegosmouth', 'mearchant': 'Khan and Sons', 'card_number': '4610081971766'}
# received msg from kafka is {'transaction_id': 'd01d57c1-5305-43b8-b28d-45513c7064b3', 'timestamp': 1742582677, 'user_id': 30818, 'amount': 1792.09, 'transaction_type': 'transfer', 'location': 'Thomasstad', 'mearchant': 'Sanders LLC', 'card_number': '6531680010526782'}
# received msg from kafka is {'transaction_id': 'ad1ef7d3-465a-46f6-9259-2d108852bd15', 'timestamp': 1742582683, 'user_id': 88439, 'amount': 1884.38, 'transaction_type': 'transfer', 'location': 'South Steven', 'mearchant': 'Floyd, Hughes and Long', 'card_number': '213123362727581'}
# received msg from kafka is {'transaction_id': 'aee847ab-696d-49c9-887d-cb374e6563a6', 'timestamp': 1742582694, 'user_id': 98826, 'amount': 285.94, 'transaction_type': 'transfer', 'location': 'North Scottshire', 'mearchant': 'Wheeler PLC', 'card_number': '2226365359444909'}
# received msg from kafka is {'transaction_id': '4057e26c-b778-4184-bcc9-0a3d71e6b6d3', 'timestamp': 1742582695, 'user_id': 63343, 'amount': 192.14, 'transaction_type': 'transfer', 'location': 'East Erin', 'mearchant': 'Erickson-Drake', 'card_number': '4985381705340'}
# received msg from kafka is {'transaction_id': '88b2979b-b2b8-465c-b073-14233ffb1976', 'timestamp': 1742582708, 'user_id': 67325, 'amount': 371.8, 'transaction_type': 'purchase', 'location': 'West Mark', 'mearchant': 'Miller-Franklin', 'card_number': '2673341866502529'}
# received msg from kafka is {'transaction_id': '47d77827-18f3-4ecc-9c08-0e33bad39884', 'timestamp': 1742582709, 'user_id': 61791, 'amount': 757.04, 'transaction_type': 'withdrawal', 'location': 'West Timothy', 'mearchant': 'Robinson, Moran and Mcneil', 'card_number': '4592750612355024957'}
# received msg from kafka is {'transaction_id': '0e159309-6e55-41ca-a1fd-b212b7bbf980', 'timestamp': 1742582711, 'user_id': 22029, 'amount': 4143.57, 'transaction_type': 'purchase', 'location': 'New Daniel', 'mearchant': 'Sanchez-Griffin', 'card_number': '4208256720141845'}
# fraud detected  {'transaction_id': '0e159309-6e55-41ca-a1fd-b212b7bbf980', 'timestamp': 1742582711, 'user_id': 22029, 'amount': 4143.57, 'transaction_type': 'purchase', 'location': 'New Daniel', 'mearchant': 'Sanchez-Griffin', 'card_number': '4208256720141845'}
# received msg from kafka is {'transaction_id': '7bb210fa-b5c8-4fb9-96df-a2c546bd794b', 'timestamp': 1742582715, 'user_id': 58386, 'amount': 1666.08, 'transaction_type': 'transfer', 'location': 'East Christopher', 'mearchant': 'Bartlett-Small', 'card_number': '4575252613896731'}
# received msg from kafka is {'transaction_id': 'e846e3ea-8037-4067-b72e-3fa032c3b915', 'timestamp': 1742582743, 'user_id': 27745, 'amount': 2476.9, 'transaction_type': 'purchase', 'location': 'West Chelseastad', 'mearchant': 'Nguyen-Jacobs', 'card_number': '4210959659798941'}
# received msg from kafka is {'transaction_id': '29aaa7b9-bec0-4616-9a34-c0c182ca3279', 'timestamp': 1742582752, 'user_id': 19093, 'amount': 1055.12, 'transaction_type': 'withdrawal', 'location': 'Lake Rodney', 'mearchant': 'Ryan, Torres and Turner', 'card_number': '345438366899504'}
# received msg from kafka is {'transaction_id': '63cc2b1c-6d7a-477d-a5c2-b45ecfc0824b', 'timestamp': 1742582765, 'user_id': 32488, 'amount': 4142.29, 'transaction_type': 'purchase', 'location': 'Port Kristaville', 'mearchant': 'Holloway, Cunningham and Smith', 'card_number': '4973685719073382534'}
# fraud detected  {'transaction_id': '63cc2b1c-6d7a-477d-a5c2-b45ecfc0824b', 'timestamp': 1742582765, 'user_id': 32488, 'amount': 4142.29, 'transaction_type': 'purchase', 'location': 'Port Kristaville', 'mearchant': 'Holloway, Cunningham and Smith', 'card_number': '4973685719073382534'}
# received msg from kafka is {'transaction_id': 'bb9ac39b-ec88-4e04-a7b1-436c2e916855', 'timestamp': 1742582773, 'user_id': 36866, 'amount': 3976.76, 'transaction_type': 'purchase', 'location': 'Stevenhaven', 'mearchant': 'Russell-Lee', 'card_number': '5177142286236159'}
# received msg from kafka is {'transaction_id': 'cbfca29e-1364-42c3-bb4c-053a4cdd4d41', 'timestamp': 1742582784, 'user_id': 10491, 'amount': 3012.03, 'transaction_type': 'purchase', 'location': 'East Shannonmouth', 'mearchant': 'Reynolds-Miller', 'card_number': '6520107932182125'}
# received msg from kafka is {'transaction_id': 'c35db6ee-a769-4f99-ba4f-c2d26f6989d2', 'timestamp': 1742582792, 'user_id': 15645, 'amount': 1188.97, 'transaction_type': 'purchase', 'location': 'New Thomas', 'mearchant': 'Doyle, Park and Davis', 'card_number': '213195845197665'}
# received msg from kafka is {'transaction_id': '35b1c079-bec1-45e7-b91f-f650a00f1234', 'timestamp': 1742582799, 'user_id': 81818, 'amount': 4858.63, 'transaction_type': 'purchase', 'location': 'Port Ericachester', 'mearchant': 'Malone-Long', 'card_number': '3531663181857498'}
# fraud detected  {'transaction_id': '35b1c079-bec1-45e7-b91f-f650a00f1234', 'timestamp': 1742582799, 'user_id': 81818, 'amount': 4858.63, 'transaction_type': 'purchase', 'location': 'Port Ericachester', 'mearchant': 'Malone-Long', 'card_number': '3531663181857498'}
# received msg from kafka is {'transaction_id': 'ef5046c6-251b-4ba2-bc90-f4150fa9db14', 'timestamp': 1742582801, 'user_id': 88777, 'amount': 3906.31, 'transaction_type': 'purchase', 'location': 'Lake Patricia', 'mearchant': 'Jordan, Allen and Harris', 'card_number': '4825569825061481635'}
# received msg from kafka is {'transaction_id': '4ff14894-8131-4759-98fa-148f79a5a4c5', 'timestamp': 1742582802, 'user_id': 98499, 'amount': 2990.03, 'transaction_type': 'purchase', 'location': 'Lake Williamborough', 'mearchant': 'Vega, Jones and Kaiser', 'card_number': '676230340926'}
# received msg from kafka is {'transaction_id': 'd5c14263-655e-4684-869a-830b0374bf45', 'timestamp': 1742582808, 'user_id': 22772, 'amount': 3596.35, 'transaction_type': 'transfer', 'location': 'Keithton', 'mearchant': 'Odom, Peterson and Lane', 'card_number': '4621079404753936'}
# received msg from kafka is {'transaction_id': '816d6c96-17f5-4eaf-b53b-2da052e96d70', 'timestamp': 1742582826, 'user_id': 29937, 'amount': 79.43, 'transaction_type': 'withdrawal', 'location': 'Janiceshire', 'mearchant': 'Morales-Smith', 'card_number': '213121308533832'}
# received msg from kafka is {'transaction_id': 'cb17f6e2-5d7c-4853-abb7-1299f390adeb', 'timestamp': 1742582833, 'user_id': 92942, 'amount': 615.94, 'transaction_type': 'withdrawal', 'location': 'New Williamstad', 'mearchant': 'Hardy Inc', 'card_number': '30544946796795'}
# received msg from kafka is {'transaction_id': '45873ca5-8422-4500-b366-b8ca3f3699db', 'timestamp': 1742582883, 'user_id': 49934, 'amount': 1033.59, 'transaction_type': 'transfer', 'location': 'Smithstad', 'mearchant': 'Park-Fox', 'card_number': '3506049386973598'}
# received msg from kafka is {'transaction_id': '7042a185-44bb-4553-9f94-6cb57401579b', 'timestamp': 1742582885, 'user_id': 46052, 'amount': 2169.14, 'transaction_type': 'withdrawal', 'location': 'Smithton', 'mearchant': 'Jordan-Pena', 'card_number': '4033929109227945'}
# received msg from kafka is {'transaction_id': 'cbc30335-132f-479c-b851-27a434f8a65d', 'timestamp': 1742582890, 'user_id': 40936, 'amount': 4385.16, 'transaction_type': 'transfer', 'location': 'Lake Lisaborough', 'mearchant': 'Cox-Price', 'card_number': '568687716908'}
# fraud detected  {'transaction_id': 'cbc30335-132f-479c-b851-27a434f8a65d', 'timestamp': 1742582890, 'user_id': 40936, 'amount': 4385.16, 'transaction_type': 'transfer', 'location': 'Lake Lisaborough', 'mearchant': 'Cox-Price', 'card_number': '568687716908'}
# received msg from kafka is {'transaction_id': '7040ed4a-71fc-4253-bade-d0cfc4c46ce0', 'timestamp': 1742580347, 'user_id': 14850, 'amount': 1358.3, 'transaction_type': 'transfer', 'location': 'Gonzalezview', 'mearchant': 'Aguirre Ltd', 'card_number': '348372016525820'}
# received msg from kafka is {'transaction_id': 'e615ff43-c7a7-4467-ac71-f8199df312f7', 'timestamp': 1742582649, 'user_id': 41115, 'amount': 1201.06, 'transaction_type': 'purchase', 'location': 'West Dennisberg', 'mearchant': 'Stephens, Martin and Baker', 'card_number': '578462824702'}
# received msg from kafka is {'transaction_id': 'c55d652a-4237-4f1e-80d1-ad6ab6308dce', 'timestamp': 1742582656, 'user_id': 78270, 'amount': 2629.86, 'transaction_type': 'withdrawal', 'location': 'New Jessicabury', 'mearchant': 'Ramirez, Miller and Nunez', 'card_number': '6597355578859468'}
# received msg from kafka is {'transaction_id': '8f8c7640-837e-4b6d-850d-31152424e154', 'timestamp': 1742582661, 'user_id': 11109, 'amount': 2684.29, 'transaction_type': 'purchase', 'location': 'Lake Justinmouth', 'mearchant': 'Reyes-Hernandez', 'card_number': '372592503729721'}
# received msg from kafka is {'transaction_id': '862f972a-91e2-42f8-b2b2-6c06916d15d2', 'timestamp': 1742582663, 'user_id': 63978, 'amount': 4737.25, 'transaction_type': 'purchase', 'location': 'Joshuatown', 'mearchant': 'Nichols-Green', 'card_number': '180094968907811'}
# fraud detected  {'transaction_id': '862f972a-91e2-42f8-b2b2-6c06916d15d2', 'timestamp': 1742582663, 'user_id': 63978, 'amount': 4737.25, 'transaction_type': 'purchase', 'location': 'Joshuatown', 'mearchant': 'Nichols-Green', 'card_number': '180094968907811'}
# received msg from kafka is {'transaction_id': 'c7959b70-f10f-4d42-b63f-762a9d0cdce1', 'timestamp': 1742582664, 'user_id': 73034, 'amount': 145.59, 'transaction_type': 'purchase', 'location': 'East Jenniferburgh', 'mearchant': 'Smith, Rodriguez and Davis', 'card_number': '4666618345903041991'}
# received msg from kafka is {'transaction_id': '81f8324f-13f5-4ce3-9c82-7067e669feba', 'timestamp': 1742582667, 'user_id': 43460, 'amount': 4157.46, 'transaction_type': 'withdrawal', 'location': 'Robertmouth', 'mearchant': 'Ortiz PLC', 'card_number': '375150096934732'}
# fraud detected  {'transaction_id': '81f8324f-13f5-4ce3-9c82-7067e669feba', 'timestamp': 1742582667, 'user_id': 43460, 'amount': 4157.46, 'transaction_type': 'withdrawal', 'location': 'Robertmouth', 'mearchant': 'Ortiz PLC', 'card_number': '375150096934732'}
# received msg from kafka is {'transaction_id': 'f024ed27-44a3-4d9c-8e6a-404d12a27bd1', 'timestamp': 1742582679, 'user_id': 35511, 'amount': 4326.12, 'transaction_type': 'withdrawal', 'location': 'Ronnieshire', 'mearchant': 'Lopez-James', 'card_number': '3580062457296376'}
# fraud detected  {'transaction_id': 'f
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# transaction_type': 'purchase', 'location': 'North Ryantown', 'mearchant': 'Rivera-Martinez', 'card_number': '4581096425721799'}
# received msg from kafka is {'transaction_id': '1304e909-9ad1-4d90-99a9-f3b38196a058', 'timestamp': 1742584725, 'user_id': 16171, 'amount': 1596.73, 'transaction_type': 'purchase', 'location': 'Michaelville', 'mearchant': 'Williams, Adkins and Bowman', 'card_number': '213167060878923'}
# received msg from kafka is {'transaction_id': '76b927b6-e9e3-42a1-ab2b-94d8b3127857', 'timestamp': 1742584727, 'user_id': 10175, 'amount': 233.52, 'transaction_type': 'withdrawal', 'location': 'Weberstad', 'mearchant': 'Howe LLC', 'card_number': '501859075167'}
# received msg from kafka is {'transaction_id': 'f02ebebb-2ed8-4c52-81f9-13c34c49579e', 'timestamp': 1742584728, 'user_id': 53609, 'amount': 1505.36, 'transaction_type': 'transfer', 'location': 'Harrellchester', 'mearchant': 'Crosby, Taylor and Kaufman', 'card_number': '4801063786618737'}
# received msg from kafka is {'transaction_id': '0a275e51-db70-4276-ade8-f7bb45dcbfbd', 'timestamp': 1742584729, 'user_id': 18551, 'amount': 1885.56, 'transaction_type': 'transfer', 'location': 'Luismouth', 'mearchant': 'Marks and Sons', 'card_number': '584166367329'}
# received msg from kafka is {'transaction_id': '0746ad25-d749-4088-91dc-f0b2d9ad5228', 'timestamp': 1742584730, 'user_id': 34951, 'amount': 3199.31, 'transaction_type': 'transfer', 'location': 'Hebertport', 'mearchant': 'Wilson Ltd', 'card_number': '3585289745449260'}
# received msg from kafka is {'transaction_id': '0168abcd-eba2-4565-bc24-5b05a5520cf4', 'timestamp': 1742584731, 'user_id': 42154, 'amount': 36.05, 'transaction_type': 'purchase', 'location': 'North Eric', 'mearchant': 'Boyd-Carpenter', 'card_number': '4033253735017715'}
# received msg from kafka is {'transaction_id': '78969a1a-0da7-4dc8-8fef-357937effbb2', 'timestamp': 1742584733, 'user_id': 57600, 'amount': 724.79, 'transaction_type': 'transfer', 'location': 'West Heatherborough', 'mearchant': 'Bailey, Greene and David', 'card_number': '4197960830941'}
# received msg from kafka is {'transaction_id': '63bfa778-f7f7-4c5d-b3bc-54308bd521e6', 'timestamp': 1742584734, 'user_id': 72004, 'amount': 2579.9, 'transaction_type': 'withdrawal', 'location': 'Sellersfurt', 'mearchant': 'Brown-Ramirez', 'card_number': '3535776013790541'}
# received msg from kafka is {'transaction_id': 'c6db4132-4c3b-4edf-8fad-a82f70c96b92', 'timestamp': 1742584735, 'user_id': 37587, 'amount': 2230.53, 'transaction_type': 'purchase', 'location': 'Chavezshire', 'mearchant': 'Dominguez-Mcgee', 'card_number': '4477380094080506'}
# received msg from kafka is {'transaction_id': 'b9af459e-0290-4218-9c8d-07dd9f9d0686', 'timestamp': 1742584736, 'user_id': 42686, 'amount': 2115.05, 'transaction_type': 'transfer', 'location': 'East Shannon', 'mearchant': 'Sharp PLC', 'card_number': '4595288912063373025'}
# received msg from kafka is {'transaction_id': '95e77688-59ab-44c1-a7f3-6aba01346b1c', 'timestamp': 1742584737, 'user_id': 84085, 'amount': 4733.81, 'transaction_type': 'withdrawal', 'location': 'South Vickiefort', 'mearchant': 'Elliott-Huffman', 'card_number': '3509792395723556'}
# fraud detected  {'transaction_id': '95e77688-59ab-44c1-a7f3-6aba01346b1c', 'timestamp': 1742584737, 'user_id': 84085, 'amount': 4733.81, 'transaction_type': 'withdrawal', 'location': 'South Vickiefort', 'mearchant': 'Elliott-Huffman', 'card_number': '3509792395723556'}
# received msg from kafka is {'transaction_id': '0c95396f-a152-421e-828b-3c977c392ada', 'timestamp': 1742584739, 'user_id': 27869, 'amount': 2263.74, 'transaction_type': 'transfer', 'location': 'Reyeshaven', 'mearchant': 'Arnold-Rivas', 'card_number': '345135273192607'}
# received msg from kafka is {'transaction_id': '79888927-740f-497b-89ba-53f39bd747b0', 'timestamp': 1742584740, 'user_id': 59457, 'amount': 1125.94, 'transaction_type': 'transfer', 'location': 'East Robin', 'mearchant': 'Mann Group', 'card_number': '4670676206494500'}
# received msg from kafka is {'transaction_id': 'fe3d7c5b-c97b-451a-b358-fde57930820f', 'timestamp': 1742584741, 'user_id': 84438, 'amount': 4642.83, 'transaction_type': 'withdrawal', 'location': 'Martineztown', 'mearchant': 'Campbell Group', 'card_number': '3557775062476427'}
# fraud detected  {'transaction_id': 'fe3d7c5b-c97b-451a-b358-fde57930820f', 'timestamp': 1742584741, 'user_id': 84438, 'amount': 4642.83, 'transaction_type': 'withdrawal', 'location': 'Martineztown', 'mearchant': 'Campbell Group', 'card_number': '3557775062476427'}
# received msg from kafka is {'transaction_id': '55221679-640f-44ba-b970-2ff2280bb90a', 'timestamp': 1742584742, 'user_id': 16417, 'amount': 3306.01, 'transaction_type': 'purchase', 'location': 'Geraldfort', 'mearchant': 'Lawrence, Nielsen and Wells', 'card_number': '501834552660'}
# received msg from kafka is {'transaction_id': 'a1bcb251-ce56-4804-9676-3b34a68ddf97', 'timestamp': 1742584743, 'user_id': 58481, 'amount': 4890.39, 'transaction_type': 'purchase', 'location': 'Vincentbury', 'mearchant': 'Ross Inc', 'card_number': '213121726104885'}
# fraud detected  {'transaction_id': 'a1bcb251-ce56-4804-9676-3b34a68ddf97', 'timestamp': 1742584743, 'user_id': 58481, 'amount': 4890.39, 'transaction_type': 'purchase', 'location': 'Vincentbury', 'mearchant': 'Ross Inc', 'card_number': '213121726104885'}
# received msg from kafka is {'transaction_id': '728182bf-55d3-49a5-9962-a34d37383a61', 'timestamp': 1742584745, 'user_id': 31992, 'amount': 1200.29, 'transaction_type': 'withdrawal', 'location': 'Livingstonview', 'mearchant': 'Hubbard PLC', 'card_number': '6011146609800987'}
# received msg from kafka is {'transaction_id': '41b3d319-2d31-45ac-ac02-9dfd16d3c22e', 'timestamp': 1742584746, 'user_id': 52430, 'amount': 896.94, 'transaction_type': 'purchase', 'location': 'Bentleyberg', 'mearchant': 'Chase-Craig', 'card_number': '3576659976350992'}
# received msg from kafka is {'transaction_id': 'ebc87a5b-dc2e-402c-9d62-29dfe906a88b', 'timestamp': 1742584747, 'user_id': 56534, 'amount': 2772.21, 'transaction_type': 'withdrawal', 'location': 'New Robertland', 'mearchant': 'Salazar Ltd', 'card_number': '180061610219820'}
# received msg from kafka is {'transaction_id': '8420d96b-6b96-4f49-b585-ce5338582d71', 'timestamp': 1742584748, 'user_id': 59509, 'amount': 1537.34, 'transaction_type': 'transfer', 'location': 'Mortonton', 'mearchant': 'Walker Inc', 'card_number': '4784395365364882'}
# received msg from kafka is {'transaction_id': '3d0c0f37-f657-40ca-bc6f-6e6f15fb84c2', 'timestamp': 1742584749, 'user_id': 39969, 'amount': 4099.06, 'transaction_type': 'withdrawal', 'location': 'Wilsonville', 'mearchant': 'Beasley, Carroll and Washington', 'card_number': '675970505698'}
# fraud detected  {'transaction_id': '3d0c0f37-f657-40ca-bc6f-6e6f15fb84c2', 'timestamp': 1742584749, 'user_id': 39969, 'amount': 4099.06, 'transaction_type': 'withdrawal', 'location': 'Wilsonville', 'mearchant': 'Beasley, Carroll and Washington', 'card_number': '675970505698'}
# received msg from kafka is {'transaction_id': 'afdc4cfb-6f3f-44ed-ac89-862080508ec9', 'timestamp': 1742584750, 'user_id': 61515, 'amount': 3972.93, 'transaction_type': 'transfer', 'location': 'Lake Carlville', 'mearchant': 'Fisher Ltd', 'card_number': '630454918149'}
# received msg from kafka is {'transaction_id': 'ae07feb3-b8d8-4a20-9b93-7dd516c9b0c0', 'timestamp': 1742584752, 'user_id': 46396, 'amount': 1738.4, 'transaction_type': 'transfer', 'location': 'Lake Daniel', 'mearchant': 'Ray, Lopez and Chang', 'card_number': '4282088963087'}
# received msg from kafka is {'transaction_id': 'd9eede96-8e08-435e-acc7-844d27f339af', 'timestamp': 1742584753, 'user_id': 35577, 'amount': 180.43, 'transaction_type': 'purchase', 'location': 'Davidmouth', 'mearchant': 'Smith Inc', 'card_number': '630478887445'}
# received msg from kafka is {'transaction_id': 'ca9a6819-ce9e-4a5a-8ead-a5084e100022', 'timestamp': 1742584754, 'user_id': 94472, 'amount': 2985.1, 'transaction_type': 'purchase', 'location': 'New Amandamouth', 'mearchant': 'Burgess-Ramirez', 'card_number': '4070225456374'}
# received msg from kafka is {'transaction_id': 'ce1a2ea8-cc54-4b03-a12c-da3d7926d19d', 'timestamp': 1742584755, 'user_id': 97119, 'amount': 2119.03, 'transaction_type': 'withdrawal', 'location': 'West Kimberlybury', 'mearchant': 'Williams, Parker and Phillips', 'card_number': '2315566845079744'}
# received msg from kafka is {'transaction_id': '3dfe5318-ea6c-4577-8824-1122d72bea79', 'timestamp': 1742584756, 'user_id': 61634, 'amount': 1677.87, 'transaction_type': 'transfer', 'location': 'New Davidton', 'mearchant': 'Marquez-Stewart', 'card_number': '6542822675014228'}
# received msg from kafka is {'transaction_id': '04c5e807-8edb-4a71-826c-dd227092f7d7', 'timestamp': 1742584758, 'user_id': 83447, 'amount': 4782.61, 'transaction_type': 'withdrawal', 'location': 'Port Micheleside', 'mearchant': 'White, Simpson and Sanders', 'card_number': '4082892744682421'}
# fraud detected  {'transaction_id': '04c5e807-8edb-4a71-826c-dd227092f7d7', 'timestamp': 1742584758, 'user_id': 83447, 'amount': 4782.61, 'transaction_type': 'withdrawal', 'location': 'Port Micheleside', 'mearchant': 'White, Simpson and Sanders', 'card_number': '4082892744682421'}
# received msg from kafka is {'transaction_id': 'a509e914-567b-4241-8ff4-fe54101a4e35', 'timestamp': 1742584759, 'user_id': 75713, 'amount': 3096.49, 'transaction_type': 'withdrawal', 'location': 'Lake Beverly', 'mearchant': 'Williams LLC', 'card_number': '4423884593682'}
# received msg from kafka is {'transaction_id': 'c870fd73-a386-4c8c-a53f-0ee41d366f58', 'timestamp': 1742584760, 'user_id': 12759, 'amount': 2568.36, 'transaction_type': 'withdrawal', 'location': 'Lake Timothymouth', 'mearchant': 'Pratt Inc', 'card_number': '4532310695503617'}
# received msg from kafka is {'transaction_id': 'b90aca82-8f59-45db-ad33-172f36b15143', 'timestamp': 1742584761, 'user_id': 42350, 'amount': 2621.43, 'transaction_type': 'transfer', 'location': 'Erikville', 'mearchant': 'Evans, Reyes and Flynn', 'card_number': '180061766335792'}
# received msg from kafka is {'transaction_id': '3007613d-4735-4f97-9197-87cc6cf3b3c7', 'timestamp': 1742584762, 'user_id': 86310, 'amount': 1983.85, 'transaction_type': 'purchase', 'location': 'New Kellytown', 'mearchant': 'Brown Ltd', 'card_number': '3533673025138987'}
# received msg from kafka is {'transaction_id': '3c4cee2e-3f86-419f-8371-ad8fdc716f52', 'timestamp': 1742584764, 'user_id': 70296, 'amount': 4499.07, 'transaction_type': 'withdrawal', 'location': 'East Shaunstad', 'mearchant': 'Brown LLC', 'card_number': '3520056129025927'}
# fraud detected  {'transaction_id': '3c4cee2e-3f86-419f-8371-ad8fdc716f52', 'timestamp': 1742584764, 'user_id': 70296, 'amount': 4499.07, 'transaction_type': 'withdrawal', 'location': 'East Shaunstad', 'mearchant': 'Brown LLC', 'card_number': '3520056129025927'}
# received msg from kafka is {'transaction_id': 'b424348b-39b2-4fd5-bbf3-e2a40da9e0d9', 'timestamp': 1742584765, 'user_id': 80747, 'amount': 4318.54, 'transaction_type': 'transfer', 'location': 'North Ericshire', 'mearchant': 'Grant-Harper', 'card_number': '4967675961076983'}
# fraud detected  {'transaction_id': 'b424348b-39b2-4fd5-bbf3-e2a40da9e0d9', 'timestamp': 1742584765, 'user_id': 80747, 'amount': 4318.54, 'transaction_type': 'transfer', 'location': 'North Ericshire', 'mearchant': 'Grant-Harper', 'card_number': '4967675961076983'}
# received msg from kafka is {'transaction_id': '62ca66b4-e6c1-4d8a-b145-c2bb1d53dfbf', 'timestamp': 1742584766, 'user_id': 71266, 'amount': 864.46, 'transaction_type': 'transfer', 'location': 'Jonesmouth', 'mearchant': 'Young-Wilson', 'card_number': '213182633417943'}
# received msg from kafka is {'transaction_id': 'af3fc69e-c20d-4d2f-aa3a-3648acb0b95a', 'timestamp': 1742584767, 'user_id': 10314, 'amount': 2878.47, 'transaction_type': 'purchase', 'location': 'East Peterville', 'mearchant': 'Rodriguez Inc', 'card_number': '502085626468'}
# received msg from kafka is {'transaction_id': '7729b1c4-3247-40c9-98d5-6fbf6c9ccc55', 'timestamp': 1742584768, 'user_id': 64524, 'amount': 3394.87, 'transaction_type': 'withdrawal', 'location': 'Brewerberg', 'mearchant': 'Williams, Hall and Castillo', 'card_number': '36261050723465'}
# received msg from kafka is {'transaction_id': '668697e6-a77c-4e3d-ad78-2780407ba276', 'timestamp': 1742584770, 'user_id': 13344, 'amount': 3670.76, 'transaction_type': 'purchase', 'location': 'Port Joy', 'mearchant': 'Pacheco Group', 'card_number': '6011018699200008'}
# received msg from kafka is {'transaction_id': 'd77306e5-5bc9-446a-9f56-bb672aab2ec4', 'timestamp': 1742584771, 'user_id': 55200, 'amount': 4708.41, 'transaction_type': 'transfer', 'location': 'Leemouth', 'mearchant': 'Clark-Beasley', 'card_number': '342936904789387'}
# fraud detected  {'transaction_id': 'd77306e5-5bc9-446a-9f56-bb672aab2ec4', 'timestamp': 1742584771, 'user_id': 55200, 'amount': 4708.41, 'transaction_type': 'transfer', 'location': 'Leemouth', 'mearchant': 'Clark-Beasley', 'card_number': '342936904789387'}
# received msg from kafka is {'transaction_id': '95dc26c3-6c5e-46bd-acf8-0e5cc0d10aa5', 'timestamp': 1742584772, 'user_id': 86219, 'amount': 3915.74, 'transaction_type': 'transfer', 'location': 'New Jacob', 'mearchant': 'King PLC', 'card_number': '4237756342231028'}
# received msg from kafka is {'transaction_id': '3002ab34-aaa6-4c23-a8eb-9ae7c881b391', 'timestamp': 1742584773, 'user_id': 21901, 'amount': 1498.53, 'transaction_type': 'withdrawal', 'location': 'Dixonburgh', 'mearchant': 'Woodard LLC', 'card_number': '060420979290'}
# received msg from kafka is {'transaction_id': 'a709f1c2-6669-4eb1-92bd-00e279ac0435', 'timestamp': 1742584774, 'user_id': 60193, 'amount': 338.54, 'transaction_type': 'withdrawal', 'location': 'South Richard', 'mearchant': 'Morgan-Martinez', 'card_number': '3512817651391932'}
# received msg from kafka is {'transaction_id': '5e06ac6f-bd35-46c4-bc20-69cf7ece7c62', 'timestamp': 1742584775, 'user_id': 65883, 'amount': 2847.41, 'transaction_type': 'transfer', 'location': 'Marshview', 'mearchant': 'James and Sons', 'card_number': '6011395444389207'}
# received msg from kafka is {'transaction_id': '5d2c81e9-10fe-4b64-bff6-6c414b7cca25', 'timestamp': 1742584777, 'user_id': 56705, 'amount': 4105.56, 'transaction_type': 'purchase', 'location': 'Ramirezport', 'mearchant': 'Miller-Scott', 'card_number': '4925161414622411819'}
# fraud detected  {'transaction_id': '5d2c81e9-10fe-4b64-bff6-6c414b7cca25', 'timestamp': 1742584777, 'user_id': 56705, 'amount': 4105.56, 'transaction_type': 'purchase', 'location': 'Ramirezport', 'mearchant': 'Miller-Scott', 'card_number': '4925161414622411819'}
# received msg from kafka is {'transaction_id': 'b8730c08-6032-42f1-aa12-a02416c3dfe5', 'timestamp': 1742584778, 'user_id': 74397, 'amount': 3791.57, 'transaction_type': 'withdrawal', 'location': 'North Michael', 'mearchant': 'Cox-Holland', 'card_number': '5449660358375763'}
# received msg from kafka is {'transaction_id': '48b2e176-6109-4f33-b5e0-de01fc2d6b5a', 'timestamp': 1742584779, 'user_id': 62084, 'amount': 652.77, 'transaction_type': 'purchase', 'location': 'West Christineside', 'mearchant': 'Owens LLC', 'card_number': '213171611989338'}
# received msg from kafka is {'transaction_id': '840cb0a7-eebb-410d-8a7d-7bb03cae5244', 'timestamp': 1742584780, 'user_id': 59048, 'amount': 759.63, 'transaction_type': 'withdrawal', 'location': 'Peterside', 'mearchant': 'Sanchez LLC', 'card_number': '5537116079021106'}
# received msg from kafka is {'transaction_id': 'c8994dfa-af4a-467c-b74a-1b786b4f0048', 'timestamp': 1742584781, 'user_id': 85325, 'amount': 2079.2, 'transaction_type': 'withdrawal', 'location': 'North Christopher', 'mearchant': 'Moon-Smith', 'card_number': '4826539156523061'}
# received msg from kafka is {'transaction_id': '0bfb4107-5c1e-4d3b-abd9-ba308239a40e', 'timestamp': 1742584783, 'user_id': 88284, 'amount': 3718.12, 'transaction_type': 'withdrawal', 'location': 'North William', 'mearchant': 'Lam LLC', 'card_number': '2278898850392059'}
# received msg from kafka is {'transaction_id': 'ed3535ea-027d-4abd-b7b1-c4473af8177b', 'timestamp': 1742584784, 'user_id': 34036, 'amount': 1680.07, 'transaction_type': 'purchase', 'location': 'Port Apriltown', 'mearchant': 'Knight-Thompson', 'card_number': '180059195966013'}
# received msg from kafka is {'transaction_id': '9ab8f817-adf7-4d63-bcc3-bc672c70ec41', 'timestamp': 1742584785, 'user_id': 64199, 'amount': 1551.22, 'transaction_type': 'withdrawal', 'location': 'New Christinaview', 'mearchant': 'Gomez Ltd', 'card_number': '4336758105195689'}
# received msg from kafka is {'transaction_id': 'a7c872ef-928b-4c00-bca2-3e9b898e102d', 'timestamp': 1742584786, 'user_id': 81814, 'amount': 4436.43, 'transaction_type': 'withdrawal', 'location': 'Jenniferberg', 'mearchant': 'Wade Group', 'card_number': '4759818406825969080'}
# fraud detected  {'transaction_id': 'a7c872ef-928b-4c00-bca2-3e9b898e102d', 'timestamp': 1742584786, 'user_id': 81814, 'amount': 4436.43, 'transaction_type': 'withdrawal', 'location': 'Jenniferberg', 'mearchant': 'Wade Group', 'card_number': '4759818406825969080'}
# received msg from kafka is {'transaction_id': '84fa9822-eb76-4a27-8c20-fb135ef158b5', 'timestamp': 1742584787, 'user_id': 90885, 'amount': 2135.55, 'transaction_type': 'withdrawal', 'location': 'New Karen', 'mearchant': 'Goodman-Lewis', 'card_number': '371277401982819'}
# received msg from kafka is {'transaction_id': 'a86a45ac-baf5-4984-bba7-1acbac00dffb', 'timestamp': 1742584789, 'user_id': 36337, 'amount': 4660.71, 'transaction_type': 'purchase', 'location': 'Brookschester', 'mearchant': 'Sherman, Aguirre and Cantrell', 'card_number': '344890648332285'}
# fraud detected  {'transaction_id': 'a86a45ac-baf5-4984-bba7-1acbac00dffb', 'timestamp': 1742584789, 'user_id': 36337, 'amount': 4660.71, 'transaction_type': 'purchase', 'location': 'Brookschester', 'mearchant': 'Sherman, Aguirre and Cantrell', 'card_number': '344890648332285'}
# received msg from kafka is {'transaction_id': '4ac82e71-83d1-427a-9380-820727aed534', 'timestamp': 1742584790, 'user_id': 75440, 'amount': 3594.32, 'transaction_type': 'purchase', 'location': 'South Jose', 'mearchant': 'Le, Davis and Douglas', 'card_number': '3558288049410823'}
# received msg from kafka is {'transaction_id': '2d3bff59-8c06-4efc-8239-3a823ae323e8', 'timestamp': 1742584791, 'user_id': 23425, 'amount': 4879.66, 'transaction_type': 'transfer', 'location': 'Lake Melissaland', 'mearchant': 'Nguyen, Johnson and Walker', 'card_number': '501874851246'}
# fraud detected  {'transaction_id': '2d3bff59-8c06-4efc-8239-3a823ae323e8', 'timestamp': 1742584791, 'user_id': 23425, 'amount': 4879.66, 'transaction_type': 'transfer', 'location': 'Lake Melissaland', 'mearchant': 'Nguyen, Johnson and Walker', 'card_number': '501874851246'}
# received msg from kafka is {'transaction_id': 'a5a643c7-9c8f-41cd-8233-6df2d35ad3af', 'timestamp': 1742584792, 'user_id': 24538, 'amount': 4962.22, 'transaction_type': 'transfer', 'location': 'Cathytown', 'mearchant': 'Graves-Steele', 'card_number': '6011418068014339'}
# fraud detected  {'transaction_id': 'a5a643c7-9c8f-41cd-8233-6df2d35ad3af', 'timestamp': 1742584792, 'user_id': 24538, 'amount': 4962.22, 'transaction_type': 'transfer', 'location': 'Cathytown', 'mearchant': 'Graves-Steele', 'card_number': '6011418068014339'}
# received msg from kafka is {'transaction_id': 'cdfa447b-1103-41bb-8c9b-3ba23ab157b4', 'timestamp': 1742584793, 'user_id': 88386, 'amount': 2091.71, 'transaction_type': 'purchase', 'location': 'North Angelaview', 'mearchant': 'Warren PLC', 'card_number': '340555553619901'}
# received msg from kafka is {'transaction_id': 'fda888bf-a1eb-4a71-a792-f394a75287cb', 'timestamp': 1742584795, 'user_id': 53987, 'amount': 2706.1, 'transaction_type': 'transfer', 'location': 'Port Gloriaview', 'mearchant': 'Hale-Ortiz', 'card_number': '4968016916098070'}
# received msg from kafka is {'transaction_id': 'b347d4b4-2fdd-4748-9a5a-0e4aeb86ff62', 'timestamp': 1742584796, 'user_id': 95861, 'amount': 4711.27, 'transaction_type': 'purchase', 'location': 'Martinfort', 'mearchant': 'Wu-Juarez', 'card_number': '4293633857704890'}
# fraud detected  {'transaction_id': 'b347d4b4-2fdd-4748-9a5a-0e4aeb86ff62', 'timestamp': 1742584796, 'user_id': 95861, 'amount': 4711.27, 'transaction_type': 'purchase', 'location': 'Martinfort', 'mearchant': 'Wu-Juarez', 'card_number': '4293633857704890'}
# received msg from kafka is {'transaction_id': 'a25a1a05-3b12-41f4-bfe7-da23b7bbfcbe', 'timestamp': 1742584797, 'user_id': 93956, 'amount': 4277.86, 'transaction_type': 'purchase', 'location': 'West Sherrychester', 'mearchant': 'Robinson Group', 'card_number': '4763422581458788'}
# fraud detected  {'transaction_id': 'a25a1a05-3b12-41f4-bfe7-da23b7bbfcbe', 'timestamp': 1742584797, 'user_id': 93956, 'amount': 4277.86, 'transaction_type': 'purchase', 'location': 'West Sherrychester', 'mearchant': 'Robinson Group', 'card_number': '4763422581458788'}
# received msg from kafka is {'transaction_id': '9e8c6e19-cc94-47c6-b08b-64697979f153', 'timestamp': 1742584798, 'user_id': 48274, 'amount': 318.98, 'transaction_type': 'purchase', 'location': 'Snowview', 'mearchant': 'Garcia Inc', 'card_number': '503805045328'}
# received msg from kafka is {'transaction_id': 'df1c6a32-0a1c-4d0f-b85e-b171e0f65ced', 'timestamp': 1742584799, 'user_id': 79229, 'amount': 1391.31, 'transaction_type': 'transfer', 'location': 'Martinstad', 'mearchant': 'Goodman Group', 'card_number': '36868997926991'}
# received msg from kafka is {'transaction_id': '5fb426af-259d-4e89-b6da-e26cd7a0d6d2', 'timestamp': 1742584800, 'user_id': 57251, 'amount': 2564.97, 'transaction_type': 'withdrawal', 'location': 'North Nancyside', 'mearchant': 'Gilbert-Anderson', 'card_number': '4027314829541487890'}
# received msg from kafka is {'transaction_id': '0e78b5fa-0328-4855-b672-22429048404f', 'timestamp': 1742584802, 'user_id': 94042, 'amount': 4431.8, 'transaction_type': 'withdrawal', 'location': 'Moralesborough', 'mearchant': 'Wilson Inc', 'card_number': '4505202541169'}
# fraud detected  {'transaction_id': '0e78b5fa-0328-4855-b672-22429048404f', 'timestamp': 1742584802, 'user_id': 94042, 'amount': 4431.8, 'transaction_type': 'withdrawal', 'location': 'Moralesborough', 'mearchant': 'Wilson Inc', 'card_number': '4505202541169'}
# received msg from kafka is {'transaction_id': 'd3e8062a-62d4-4081-82da-cb75b3a56648', 'timestamp': 1742584803, 'user_id': 94817, 'amount': 2281.35, 'transaction_type': 'withdrawal', 'location': 'West Hayley', 'mearchant': 'Edwards and Sons', 'card_number': '370062446526958'}
# received msg from kafka is {'transaction_id': '0fffd9fe-1281-4fa3-8606-3f7c863d3643', 'timestamp': 1742584804, 'user_id': 42383, 'amount': 2611.57, 'transaction_type': 'purchase', 'location': 'North Drewbury', 'mearchant': 'Johnson Ltd', 'card_number': '2715753290245071'}
# received msg from kafka is {'transaction_id': '44615a4d-b139-440b-9812-5a1d46d48457', 'timestamp': 1742584805, 'user_id': 21013, 'amount': 2651.82, 'transaction_type': 'withdrawal', 'location': 'Gonzalezbury', 'mearchant': 'Reid LLC', 'card_number': '4883798679351158'}
# received msg from kafka is {'transaction_id': '5d1b665b-2dcf-41a2-81d4-bd12c1a84436', 'timestamp': 1742584806, 'user_id': 37873, 'amount': 3712.48, 'transaction_type': 'withdrawal', 'location': 'South Chelsea', 'mearchant': 'Johnson, Jackson and Miles', 'card_number': '6011181128328111'}
# received msg from kafka is {'transaction_id': 'b999c3a7-5c09-45ed-b988-801902f62c22', 'timestamp': 1742584808, 'user_id': 79146, 'amount': 2666.35, 'transaction_type': 'transfer', 'location': 'Sharpville', 'mearchant': 'Alexander, Saunders and Martinez', 'card_number': '4650363494401405141'}
# received msg from kafka is {'transaction_id': '1eca473b-09e3-4db8-ac59-ce5614203b56', 'timestamp': 1742584809, 'user_id': 39614, 'amount': 3462.64, 'transaction_type': 'withdrawal', 'location': 'Hollandview', 'mearchant': 'Smith, Baker and Smith', 'card_number': '4700144514370'}
# received msg from kafka is {'transaction_id': 'b6b0e0fe-c9a8-4886-8c40-287ce067809e', 'timestamp': 1742584810, 'user_id': 82622, 'amount': 1437.9, 'transaction_type': 'transfer', 'location': 'North James', 'mearchant': 'Boyer-Frazier', 'card_number': '6011990060826019'}
# received msg from kafka is {'transaction_id': '16f092fd-b36c-436f-8de7-56e7ad78dd63', 'timestamp': 1742584811, 'user_id': 89487, 'amount': 3450.9, 'transaction_type': 'transfer', 'location': 'West Jamiechester', 'mearchant': 'Smith, Rush and Howell', 'card_number': '4622657621976221'}
# received msg from kafka is {'transaction_id': '7a210f9e-c9ec-4ec8-bfc9-461b292fef32', 'timestamp': 1742584812, 'user_id': 83912, 'amount': 127.89, 'transaction_type': 'transfer', 'location': 'Lake Christineshire', 'mearchant': 'Wolf, Bush and Butler', 'card_number': '4241733474170302'}
# received msg from kafka is {'transaction_id': '7a76d729-fe4d-4be0-8af5-a796532ccfd9', 'timestamp': 1742584814, 'user_id': 53163, 'amount': 3578.59, 'transaction_type': 'withdrawal', 'location': 'West Kristen', 'mearchant': 'Ramos PLC', 'card_number': '5300370748463091'}
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
pip install confluent_kafka
# Out:
# Python interpreter will be restarted.
# Collecting confluent_kafka
#   Using cached confluent_kafka-2.8.2-cp39-cp39-manylinux_2_28_x86_64.whl (3.8 MB)
# Installing collected packages: confluent-kafka
# Successfully installed confluent-kafka-2.8.2
# Python interpreter will be restarted.

# %%
pip install pymongo
# Out:
# Python interpreter will be restarted.
# Collecting pymongo
#   Downloading pymongo-4.11.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (921 kB)
# Collecting dnspython<3.0.0,>=1.16.0
#   Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.11.3
# Python interpreter will be restarted.
